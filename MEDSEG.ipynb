# %% [markdown]
# # Setup
# Downloading required pip packages and the preview dataset

# %%
# !pip install TotalSegmentator "pyvista[jupyter]" "jupyterlab" SimpleITK medim monai --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 128.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.7/244.7 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.5/751.5 kB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 96.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 86.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 96.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 116.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 9.4 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (setup.py) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Building wheel for dynamic-network-architectures (setup.py) ... done

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1mgwuCpvTc3INnqGHiXhxJsbEzZPasplx" -O CT_subset_big.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1mgwuCpvTc3INnqGHiXhxJsbEzZPasplx
# From (redirected): https://drive.google.com/uc?export=download&id=1mgwuCpvTc3INnqGHiXhxJsbEzZPasplx&confirm=t&uuid=881595d1-c127-4a3f-ab03-cbe58e140f9f
# To: /content/CT_subset_big.zip
# 100% 452M/452M [00:06<00:00, 65.6MB/s]

# %%
# !unzip CT_subset_big.zip -d CT_Set
# Out:
# Archive:  CT_subset_big.zip
#    creating: CT_Set/s0000/
#    creating: CT_Set/s0000/segmentations/
#   inflating: CT_Set/s0000/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0000/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0000/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0000/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0000/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0000/segmentations/brain.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0000/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0000/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0000/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0000/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0000/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0000/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0000/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0000/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0000/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0000/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/colon.nii.gz
#   inflating: CT_Set/s0000/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0000/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0000/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0000/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0000/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0000/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0000/segmentations/heart.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0000/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0000/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0000/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0000/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0000/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/skull.nii.gz
#   inflating: CT_Set/s0000/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0000/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0000/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0000/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0000/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0000/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0000/segmentations/liver.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0000/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0000/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0000/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0000/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0000/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0000/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0000/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0000/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0000/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0000/ct.nii.gz
#    creating: CT_Set/s0001/
#    creating: CT_Set/s0001/segmentations/
#   inflating: CT_Set/s0001/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0001/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0001/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0001/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0001/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0001/segmentations/brain.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0001/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0001/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0001/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0001/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0001/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0001/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0001/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0001/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0001/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0001/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/colon.nii.gz
#   inflating: CT_Set/s0001/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0001/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0001/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0001/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0001/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0001/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0001/segmentations/heart.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0001/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0001/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0001/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0001/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0001/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/skull.nii.gz
#   inflating: CT_Set/s0001/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0001/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0001/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0001/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0001/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0001/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0001/segmentations/liver.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0001/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0001/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0001/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0001/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0001/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0001/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0001/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0001/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0001/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0001/ct.nii.gz
#    creating: CT_Set/s0002/
#    creating: CT_Set/s0002/segmentations/
#   inflating: CT_Set/s0002/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0002/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0002/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0002/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0002/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0002/segmentations/brain.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0002/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0002/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0002/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0002/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0002/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0002/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0002/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0002/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0002/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0002/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/colon.nii.gz
#   inflating: CT_Set/s0002/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0002/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0002/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0002/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0002/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0002/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0002/segmentations/heart.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0002/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0002/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0002/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0002/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0002/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/skull.nii.gz
#   inflating: CT_Set/s0002/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0002/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0002/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0002/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0002/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0002/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0002/segmentations/liver.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0002/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0002/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0002/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0002/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0002/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0002/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0002/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0002/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0002/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0002/ct.nii.gz
#    creating: CT_Set/s0003/
#    creating: CT_Set/s0003/segmentations/
#   inflating: CT_Set/s0003/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0003/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0003/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0003/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0003/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0003/segmentations/brain.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0003/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0003/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0003/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0003/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0003/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0003/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0003/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0003/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0003/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0003/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/colon.nii.gz
#   inflating: CT_Set/s0003/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0003/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0003/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0003/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0003/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0003/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0003/segmentations/heart.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0003/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0003/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0003/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0003/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0003/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/skull.nii.gz
#   inflating: CT_Set/s0003/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0003/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0003/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0003/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0003/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0003/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0003/segmentations/liver.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0003/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0003/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0003/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0003/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0003/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0003/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0003/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0003/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0003/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0003/ct.nii.gz
#    creating: CT_Set/s0004/
#    creating: CT_Set/s0004/segmentations/
#   inflating: CT_Set/s0004/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0004/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0004/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0004/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0004/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0004/segmentations/brain.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0004/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0004/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0004/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0004/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0004/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0004/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0004/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0004/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0004/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0004/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/colon.nii.gz
#   inflating: CT_Set/s0004/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0004/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0004/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0004/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0004/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0004/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0004/segmentations/heart.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0004/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0004/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0004/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0004/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0004/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/skull.nii.gz
#   inflating: CT_Set/s0004/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0004/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0004/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0004/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0004/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0004/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0004/segmentations/liver.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0004/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0004/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0004/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0004/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0004/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0004/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0004/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0004/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0004/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0004/ct.nii.gz
#    creating: CT_Set/s0006/
#    creating: CT_Set/s0006/segmentations/
#   inflating: CT_Set/s0006/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0006/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0006/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0006/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0006/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0006/segmentations/brain.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0006/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0006/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0006/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0006/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0006/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0006/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0006/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0006/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0006/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0006/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/colon.nii.gz
#   inflating: CT_Set/s0006/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0006/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0006/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0006/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0006/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0006/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0006/segmentations/heart.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0006/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0006/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0006/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0006/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0006/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/skull.nii.gz
#   inflating: CT_Set/s0006/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0006/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0006/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0006/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0006/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0006/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0006/segmentations/liver.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0006/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0006/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0006/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0006/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0006/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0006/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0006/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0006/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0006/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0006/ct.nii.gz
#    creating: CT_Set/s0009/
#    creating: CT_Set/s0009/segmentations/
#   inflating: CT_Set/s0009/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0009/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0009/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0009/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0009/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0009/segmentations/brain.nii.gz
#   inflating: CT_Set/s0009/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0009/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0009/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0009/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0009/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0009/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0009/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0009/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0009/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0009/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0009/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0009/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0009/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0009/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0009/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0009/segmentations/colon.nii.gz
#   inflating: CT_Set/s0009/segmentations/superior_vena_cava.nii.gz
# ...
#   inflating: CT_Set/s0025/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0025/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0025/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0025/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0025/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0025/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0025/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0025/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0025/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0025/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0025/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0025/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0025/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0025/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0025/ct.nii.gz
#    creating: CT_Set/s0028/
#    creating: CT_Set/s0028/segmentations/
#   inflating: CT_Set/s0028/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0028/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0028/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0028/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0028/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0028/segmentations/brain.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0028/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0028/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0028/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0028/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0028/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0028/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0028/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0028/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0028/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0028/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/colon.nii.gz
#   inflating: CT_Set/s0028/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0028/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0028/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0028/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0028/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0028/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0028/segmentations/heart.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0028/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0028/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0028/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0028/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0028/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/skull.nii.gz
#   inflating: CT_Set/s0028/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0028/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0028/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0028/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0028/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0028/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0028/segmentations/liver.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0028/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0028/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0028/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0028/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0028/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0028/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0028/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0028/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0028/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0028/ct.nii.gz
#    creating: CT_Set/s0029/
#    creating: CT_Set/s0029/segmentations/
#   inflating: CT_Set/s0029/segmentations/iliopsoas_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/iliac_artery_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/inferior_vena_cava.nii.gz
#   inflating: CT_Set/s0029/segmentations/iliac_vena_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/duodenum.nii.gz
#   inflating: CT_Set/s0029/segmentations/trachea.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_10.nii.gz
#   inflating: CT_Set/s0029/segmentations/common_carotid_artery_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_11.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_12.nii.gz
#   inflating: CT_Set/s0029/segmentations/sternum.nii.gz
#   inflating: CT_Set/s0029/segmentations/brain.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C2.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C4.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_L2.nii.gz
#   inflating: CT_Set/s0029/segmentations/subclavian_artery_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_1.nii.gz
#   inflating: CT_Set/s0029/segmentations/gluteus_medius_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/pancreas.nii.gz
#   inflating: CT_Set/s0029/segmentations/gluteus_minimus_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/humerus_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/esophagus.nii.gz
#   inflating: CT_Set/s0029/segmentations/clavicula_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/subclavian_artery_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/portal_vein_and_splenic_vein.nii.gz
#   inflating: CT_Set/s0029/segmentations/hip_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/brachiocephalic_vein_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/adrenal_gland_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_3.nii.gz
#   inflating: CT_Set/s0029/segmentations/scapula_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/lung_lower_lobe_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_2.nii.gz
#   inflating: CT_Set/s0029/segmentations/autochthon_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C6.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_4.nii.gz
#   inflating: CT_Set/s0029/segmentations/brachiocephalic_trunk.nii.gz
#   inflating: CT_Set/s0029/segmentations/gluteus_maximus_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/spinal_cord.nii.gz
#   inflating: CT_Set/s0029/segmentations/atrial_appendage_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/common_carotid_artery_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/colon.nii.gz
#   inflating: CT_Set/s0029/segmentations/superior_vena_cava.nii.gz
#   inflating: CT_Set/s0029/segmentations/femur_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T6.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_8.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_6.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_5.nii.gz
#   inflating: CT_Set/s0029/segmentations/aorta.nii.gz
#   inflating: CT_Set/s0029/segmentations/lung_middle_lobe_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T12.nii.gz
#   inflating: CT_Set/s0029/segmentations/clavicula_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T4.nii.gz
#   inflating: CT_Set/s0029/segmentations/urinary_bladder.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_L4.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_3.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T7.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T5.nii.gz
#   inflating: CT_Set/s0029/segmentations/heart.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C5.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_5.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_L5.nii.gz
#   inflating: CT_Set/s0029/segmentations/pulmonary_vein.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T3.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_L3.nii.gz
#   inflating: CT_Set/s0029/segmentations/stomach.nii.gz
#   inflating: CT_Set/s0029/segmentations/humerus_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_4.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_12.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_L1.nii.gz
#   inflating: CT_Set/s0029/segmentations/gluteus_maximus_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/kidney_cyst_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/gallbladder.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_S1.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T8.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C7.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T1.nii.gz
#   inflating: CT_Set/s0029/segmentations/lung_upper_lobe_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/skull.nii.gz
#   inflating: CT_Set/s0029/segmentations/kidney_cyst_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_2.nii.gz
#   inflating: CT_Set/s0029/segmentations/thyroid_gland.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_9.nii.gz
#   inflating: CT_Set/s0029/segmentations/iliac_artery_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_11.nii.gz
#   inflating: CT_Set/s0029/segmentations/iliac_vena_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/hip_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C1.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_6.nii.gz
#   inflating: CT_Set/s0029/segmentations/costal_cartilages.nii.gz
#   inflating: CT_Set/s0029/segmentations/autochthon_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_10.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_8.nii.gz
#   inflating: CT_Set/s0029/segmentations/liver.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_9.nii.gz
#   inflating: CT_Set/s0029/segmentations/kidney_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_1.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_C3.nii.gz
#   inflating: CT_Set/s0029/segmentations/brachiocephalic_vein_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/sacrum.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T2.nii.gz
#   inflating: CT_Set/s0029/segmentations/lung_lower_lobe_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/gluteus_minimus_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/small_bowel.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T10.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T11.nii.gz
#   inflating: CT_Set/s0029/segmentations/vertebrae_T9.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_left_7.nii.gz
#   inflating: CT_Set/s0029/segmentations/lung_upper_lobe_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/kidney_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/femur_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/adrenal_gland_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/rib_right_7.nii.gz
#   inflating: CT_Set/s0029/segmentations/iliopsoas_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/scapula_right.nii.gz
#   inflating: CT_Set/s0029/segmentations/spleen.nii.gz
#   inflating: CT_Set/s0029/segmentations/gluteus_medius_left.nii.gz
#   inflating: CT_Set/s0029/segmentations/prostate.nii.gz
#   inflating: CT_Set/s0029/ct.nii.gz

# %% [markdown]
# # Segmentation

# %%
# @title ##### Select one of the included preview CT scans as well as the AI model to use:
import ipywidgets as widgets
from IPython.display import display, clear_output
import os

# Get list of subject folders in CT_Set
ct_set_path = "CT_Set"
subject_folders = [f.path for f in os.scandir(ct_set_path) if f.is_dir() and f.name.startswith('s')]
subject_folders.sort()

# Create a dropdown widget to select a subject folder
subject_selector = widgets.Dropdown(
    options=subject_folders,
    description='Select Subject Folder:',
    disabled=False,
    style = {'description_width': '150px'}
)

# Define the available models
available_models = ['totalSegmentator', 'MONAI SegResNet', 'STU-Net-B']

# Create a dropdown widget for model selection
model_selector = widgets.Dropdown(
    options=available_models,
    description='Select AI Model:',
    disabled=False,
    style = {'description_width': '150px'}
)

display(subject_selector, model_selector)
# Out:
# Dropdown(description='Select Subject Folder:', options=('CT_Set/s0000', 'CT_Set/s0001', 'CT_Set/s0002', 'CT_Se…
# Dropdown(description='Select AI Model:', options=('totalSegmentator', 'MONAI SegResNet', 'STU-Net-B'), style=D…

# %%
# @title Visualize the selected CT scan (optional)
import nibabel as nib
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interactive, Output
import os
from IPython.display import display

selected_folder = subject_selector.value

# Load the NIfTI file
file_path = os.path.join(selected_folder, "ct.nii.gz")
img = nib.load(file_path)
data = img.get_fdata()

# Get dimensions
n_slices_axial = data.shape[2]
n_slices_coronal = data.shape[1]
n_slices_sagittal = data.shape[0]

# Outputs for manual layout
out_axial = Output()
out_coronal = Output()
out_sagittal = Output()

# Define slice viewers for each axis
def view_axial_slice(slice_idx):
    with out_axial:
        out_axial.clear_output(wait=True)
        plt.figure(figsize=(4, 4))
        plt.imshow(data[:, :, slice_idx].T, cmap="gray", origin="lower")
        plt.title(f"Axial {slice_idx}")
        plt.axis("off")
        plt.show()

def view_coronal_slice(slice_idx):
    with out_coronal:
        out_coronal.clear_output(wait=True)
        plt.figure(figsize=(4, 4))
        plt.imshow(data[:, slice_idx, :].T, cmap="gray", origin="lower")
        plt.title(f"Coronal {slice_idx}")
        plt.axis("off")
        plt.show()

def view_sagittal_slice(slice_idx):
    with out_sagittal:
        out_sagittal.clear_output(wait=True)
        plt.figure(figsize=(4, 4))
        plt.imshow(data[slice_idx, :, :].T, cmap="gray", origin="lower")
        plt.title(f"Sagittal {slice_idx}")
        plt.axis("off")
        plt.show()

# Sliders
axial_slider = widgets.IntSlider(min=0, max=n_slices_axial - 1, value=n_slices_axial // 2, description="Axial")
coronal_slider = widgets.IntSlider(min=0, max=n_slices_coronal - 1, value=n_slices_coronal // 2, description="Coronal")
sagittal_slider = widgets.IntSlider(min=0, max=n_slices_sagittal - 1, value=n_slices_sagittal // 2, description="Sagittal")

# Link sliders to update functions
widgets.interactive_output(view_axial_slice, {'slice_idx': axial_slider})
widgets.interactive_output(view_coronal_slice, {'slice_idx': coronal_slider})
widgets.interactive_output(view_sagittal_slice, {'slice_idx': sagittal_slider})

# Show initial slices
view_axial_slice(axial_slider.value)
view_coronal_slice(coronal_slider.value)
view_sagittal_slice(sagittal_slider.value)

# Layout: three images in a row, sliders below
display(
    widgets.VBox([
        widgets.HBox([out_axial, out_coronal, out_sagittal]),
        widgets.HBox([axial_slider, coronal_slider, sagittal_slider])
    ])
)
# Out:
# VBox(children=(HBox(children=(Output(), Output(), Output())), HBox(children=(IntSlider(value=220, description=…

# %%
# @title Run inference and process output
from totalsegmentator.python_api import totalsegmentator
import requests
from google.colab import userdata
import os
import shutil
import zipfile
import io
import os
import nibabel as nib
import torch
import numpy as np
from monai.bundle import download
from monai.inferers import sliding_window_inference
from monai.transforms import (
    LoadImaged, Spacingd, Orientationd, ScaleIntensityd,
    EnsureTyped, EnsureChannelFirstd
)
from monai.data import Dataset, DataLoader
from monai.networks.nets import SegResNet
import medim
import torch.nn.functional as F


selected_folder = subject_selector.value

input_file = os.path.join(selected_folder, "ct.nii.gz")

output_dir = "output_segments"


# Delete the output directory if it exists
if os.path.exists(output_dir):
    shutil.rmtree(output_dir)

# Create the output directory
os.makedirs(output_dir, exist_ok=True)


def save_segmentations_by_organ(prediction_array, input_nii_path, output_dir, channel_def):
    """
    Saves individual organ segmentations from a prediction array.

    Args:
        prediction_array (np.ndarray): The predicted segmentation array.
        input_nii_path (str): Path to the original input NIfTI file (for affine and header).
        output_dir (str): Directory to save the individual organ segmentation files.
        channel_def (dict): Dictionary mapping organ IDs to organ names.
    """
    img_nib = nib.load(input_nii_path)
    affine = img_nib.affine
    header = img_nib.header

    os.makedirs(output_dir, exist_ok=True)

    # Get unique organ IDs present in the prediction (excluding background)
    organ_ids = np.unique(prediction_array)
    organ_ids = organ_ids[organ_ids != 0] # Exclude background (assuming 0 is background)


    for organ_id in organ_ids:
        mask = (prediction_array == organ_id).astype(np.uint8)
        if mask.sum() == 0:
            continue  # skip empty masks
        # Get organ name from channel_def
        organ_name = channel_def.get(organ_id, f"organ_{organ_id}") # Use organ_id as fallback
        out_img = nib.Nifti1Image(mask, affine, header)
        nib.save(out_img, os.path.join(output_dir, f"{organ_name}.nii.gz"))
    print(f"Saved {len(organ_ids)} individual organ segmentation files to {output_dir}")


# Define channel definition for MONAI SegResNet
monai_channel_def = {
    0: "background",
    1: "spleen",
    2: "kidney_right",
    3: "kidney_left",
    4: "gallbladder",
    5: "liver",
    6: "stomach",
    7: "aorta",
    8: "inferior_vena_cava",
    9: "portal_vein_and_splenic_vein",
    10: "pancreas",
    11: "adrenal_gland_right",
    12: "adrenal_gland_left",
    13: "lung_upper_lobe_left",
    14: "lung_lower_lobe_left",
    15: "lung_upper_lobe_right",
    16: "lung_middle_lobe_right",
    17: "lung_lower_lobe_right",
    18: "vertebrae_L5",
    19: "vertebrae_L4",
    20: "vertebrae_L3",
    21: "vertebrae_L2",
    22: "vertebrae_L1",
    23: "vertebrae_T12",
    24: "vertebrae_T11",
    25: "vertebrae_T10",
    26: "vertebrae_T9",
    27: "vertebrae_T8",
    28: "vertebrae_T7",
    29: "vertebrae_T6",
    30: "vertebrae_T5",
    31: "vertebrae_T4",
    32: "vertebrae_T3",
    33: "vertebrae_T2",
    34: "vertebrae_T1",
    35: "vertebrae_C7",
    36: "vertebrae_C6",
    37: "vertebrae_C5",
    38: "vertebrae_C4",
    39: "vertebrae_C3",
    40: "vertebrae_C2",
    41: "vertebrae_C1",
    42: "esophagus",
    43: "trachea",
    44: "heart_myocardium",
    45: "heart_atrium_left",
    46: "heart_ventricle_left",
    47: "heart_atrium_right",
    48: "heart_ventricle_right",
    49: "pulmonary_artery",
    50: "brain",
    51: "iliac_artery_left",
    52: "iliac_artery_right",
    53: "iliac_vena_left",
    54: "iliac_vena_right",
    55: "small_bowel",
    56: "duodenum",
    57: "colon",
    58: "rib_left_1",
    59: "rib_left_2",
    60: "rib_left_3",
    61: "rib_left_4",
    62: "rib_left_5",
    63: "rib_left_6",
    64: "rib_left_7",
    65: "rib_left_8",
    66: "rib_left_9",
    67: "rib_left_10",
    68: "rib_left_11",
    69: "rib_left_12",
    70: "rib_right_1",
    71: "rib_right_2",
    72: "rib_right_3",
    73: "rib_right_4",
    74: "rib_right_5",
    75: "rib_right_6",
    76: "rib_right_7",
    77: "rib_right_8",
    78: "rib_right_9",
    79: "rib_right_10",
    80: "rib_right_11",
    81: "rib_right_12",
    82: "humerus_left",
    83: "humerus_right",
    84: "scapula_left",
    85: "scapula_right",
    86: "clavicula_left",
    87: "clavicula_right",
    88: "femur_left",
    89: "femur_right",
    90: "hip_left",
    91: "hip_right",
    92: "sacrum",
    93: "face",
    94: "gluteus_maximus_left",
    95: "gluteus_maximus_right",
    96: "gluteus_medius_left",
    97: "gluteus_medius_right",
    98: "gluteus_minimus_left",
    99: "gluteus_minimus_right",
    100: "autochthon_left",
    101: "autochthon_right",
    102: "iliopsoas_left",
    103: "iliopsoas_right",
    104: "urinary_bladder"
}

# Define channel definition for STU-Net
stunet_channel_def = {
    0: "background",
    1: "adrenal_gland_left",
    2: "adrenal_gland_right",
    3: "aorta",
    4: "autochthon_left",
    5: "autochthon_right",
    6: "brain",
    7: "clavicula_left",
    8: "clavicula_right",
    9: "colon",
    10: "duodenum",
    11: "esophagus",
    12: "face",
    13: "femur_left",
    14: "femur_right",
    15: "gallbladder",
    16: "gluteus_maximus_left",
    17: "gluteus_maximus_right",
    18: "gluteus_medius_left",
    19: "gluteus_medius_right",
    20: "gluteus_minimus_left",
    21: "gluteus_minimus_right",
    22: "heart_atrium_left",
    23: "heart_atrium_right",
    24: "heart_myocardium",
    25: "heart_ventricle_left",
    26: "heart_ventricle_right",
    27: "hip_left",
    28: "hip_right",
    29: "humerus_left",
    30: "humerus_right",
    31: "iliac_artery_left",
    32: "iliac_artery_right",
    33: "iliac_vena_left",
    34: "iliac_vena_right",
    35: "iliopsoas_left",
    36: "iliopsoas_right",
    37: "inferior_vena_cava",
    38: "kidney_left",
    39: "kidney_right",
    40: "liver",
    41: "lung_lower_lobe_left",
    42: "lung_lower_lobe_right",
    43: "lung_middle_lobe_right",
    44: "lung_upper_lobe_left",
    45: "lung_upper_lobe_right",
    46: "pancreas",
    47: "portal_vein_and_splenic_vein",
    48: "pulmonary_artery",
    49: "rib_left_1",
    50: "rib_left_10",
    51: "rib_left_11",
    52: "rib_left_12",
    53: "rib_left_2",
    54: "rib_left_3",
    55: "rib_left_4",
    56: "rib_left_5",
    57: "rib_left_6",
    58: "rib_left_7",
    59: "rib_left_8",
    60: "rib_left_9",
    61: "rib_right_1",
    62: "rib_right_10",
    63: "rib_right_11",
    64: "rib_right_12",
    65: "rib_right_2",
    66: "rib_right_3",
    67: "rib_right_4",
    68: "rib_right_5",
    69: "rib_right_6",
    70: "rib_right_7",
    71: "rib_right_8",
    72: "rib_right_9",
    73: "sacrum",
    74: "scapula_left",
    75: "scapula_right",
    76: "small_bowel",
    77: "spleen",
    78: "stomach",
    79: "trachea",
    80: "urinary_bladder",
    81: "vertebrae_C1",
    82: "vertebrae_C2",
    83: "vertebrae_C3",
    84: "vertebrae_C4",
    85: "vertebrae_C5",
    86: "vertebrae_C6",
    87: "vertebrae_C7",
    88: "vertebrae_L1",
    89: "vertebrae_L2",
    90: "vertebrae_L3",
    91: "vertebrae_L4",
    92: "vertebrae_L5",
    93: "vertebrae_T1",
    94: "vertebrae_T10",
    95: "vertebrae_T11",
    96: "vertebrae_T12",
    97: "vertebrae_T2",
    98: "vertebrae_T3",
    99: "vertebrae_T4",
    100: "vertebrae_T5",
    101: "vertebrae_T6",
    102: "vertebrae_T7",
    103: "vertebrae_T8",
    104: "vertebrae_T9"
}

match model_selector.value:
    case 'totalSegmentator':
        totalsegmentator(input_file, output_dir)

        # Post-processing: Remove empty NIfTI files
        for file_name in os.listdir(output_dir):
            file_path = os.path.join(output_dir, file_name)
            if file_name.endswith(".nii.gz"):
                try:
                    img = nib.load(file_path)
                    data = img.get_fdata()
                    if np.count_nonzero(data) < 5: # Threshold for considering a mask empty
                        print(f"Removing empty segmentation file: {file_name}")
                        os.remove(file_path)
                except Exception as e:
                    print(f"Error checking file {file_name}: {e}")


    case 'MONAI SegResNet':

        # =========================================
        # MONAI SegResNet Download
        # =========================================
        bundle_dir = "./wholebody_ct"
        os.makedirs(bundle_dir, exist_ok=True)
        # !wget -O {bundle_dir}/model.pt https://huggingface.co/MONAI/wholeBody_ct_segmentation/resolve/0.2.7/models/model.pt

        # ===================================================
        # 2. Load Model
        # ===================================================

        # SegResNet model definition (from MONAI bundle)
        model = SegResNet(
            spatial_dims=3,
            in_channels=1,
            out_channels=105,   # 104 organs + background
            init_filters=32,
            blocks_down=[1, 2, 2, 4],
            blocks_up=[1, 1, 1]
        )


        ckpt = torch.load(f"{bundle_dir}/model.pt", map_location="cpu")

        model.load_state_dict(ckpt, strict=True)
        model.eval().cuda()

        # ===================================================
        # 3. Preprocessing
        # ===================================================

        from monai.transforms import Compose

        pre_transforms = Compose([
            LoadImaged(keys=["image"]),
            EnsureChannelFirstd(keys=["image"]),
            Spacingd(keys=["image"], pixdim=(1.5, 1.5, 1.5), mode="bilinear"),
            Orientationd(keys=["image"], axcodes="RAS"),
            ScaleIntensityd(keys=["image"]),
            EnsureTyped(keys=["image"])
        ])

        # ===================================================
        # 4. Inference
        # ===================================================

        def run_inference(input_path):
            data = [{"image": input_path}]
            dataset = Dataset(data=data, transform=pre_transforms)
            loader = DataLoader(dataset, batch_size=1)

            with torch.no_grad():
                for batch in loader:
                    image = batch["image"].cuda()
                    pred = sliding_window_inference(
                        inputs=image,
                        roi_size=(96, 96, 96),
                        sw_batch_size=1,
                        predictor=model,
                        overlap=0.5
                    )
                    # Get the prediction array
                    prediction_array = torch.argmax(pred, dim=1).cpu().numpy()[0]
                    return prediction_array

        # Run inference and save segmentations
        monai_prediction = run_inference(input_file)
        save_segmentations_by_organ(monai_prediction, input_file, output_dir, monai_channel_def)
        del model
        torch.cuda.empty_cache()

    case 'STU-Net-B':
        # ===================================================
        # 1. Load STU-Net-B with dataset parameter
        # ===================================================
        model = medim.create_model("STU-Net-B", dataset="TotalSegmentator")
        model.eval().cuda()

        # ===================================================
        # 2. Load and preprocess NIfTI input
        # ===================================================
        img = nib.load(input_file)
        img_data = img.get_fdata()

        # Normalize input (crucial step!)
        img_data = (img_data - img_data.mean()) / (img_data.std() + 1e-8)

        input_tensor = torch.tensor(
            img_data, dtype=torch.float32
        ).unsqueeze(0).unsqueeze(0).cuda()

        # ===================================================
        # 3. Sliding Window Inference
        # ===================================================
        with torch.no_grad():
            pred_logits = sliding_window_inference(
                inputs=input_tensor,
                roi_size=(96, 96, 96),
                sw_batch_size=1,
                predictor=model,
                overlap=0.5
            )
            prediction = torch.argmax(pred_logits, dim=1).squeeze().cpu().numpy()

        # ===================================================
        # 4. Save segmentations
        # ===================================================
        save_segmentations_by_organ(prediction, input_file, output_dir, stunet_channel_def)

        # ===================================================
        # 5. Cleanup
        # ===================================================
        model.cpu()
        del model, input_tensor, pred_logits, prediction
        torch.cuda.empty_cache()
# Out:
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# TotalSegmentator sends anonymous usage statistics. If you want to disable it check the documentation.
# Downloading model for Task 291 ...
# Downloading: 100%|██████████| 234M/234M [00:02<00:00, 115MB/s]
# Download finished. Extracting...
# Downloading model for Task 292 ...
# Downloading: 100%|██████████| 234M/234M [00:02<00:00, 117MB/s]
# Download finished. Extracting...
# Downloading model for Task 293 ...
# Downloading: 100%|██████████| 234M/234M [00:02<00:00, 116MB/s]
# Download finished. Extracting...
# Downloading model for Task 294 ...
# Downloading: 100%|██████████| 234M/234M [00:01<00:00, 123MB/s]
# Download finished. Extracting...
# Downloading model for Task 295 ...
# Downloading: 100%|██████████| 234M/234M [00:01<00:00, 123MB/s]
# Download finished. Extracting...
# Resampling...
#   Resampled in 4.37s
# Predicting part 1 of 5 ...
# 100%|██████████| 12/12 [00:04<00:00,  2.82it/s]
# Predicting part 2 of 5 ...
# 100%|██████████| 12/12 [00:01<00:00, 11.74it/s]
# Predicting part 3 of 5 ...
# 100%|██████████| 12/12 [00:00<00:00, 12.12it/s]
# Predicting part 4 of 5 ...
# 100%|██████████| 12/12 [00:01<00:00, 11.66it/s]
# Predicting part 5 of 5 ...
# 100%|██████████| 12/12 [00:00<00:00, 12.76it/s]
#   Predicted in 82.89s
# Resampling...
# Saving segmentations...
#   Saved in 8.88s
# Removing empty segmentation file: vertebrae_T6.nii.gz
# Removing empty segmentation file: rib_left_3.nii.gz
# Removing empty segmentation file: liver.nii.gz
# Removing empty segmentation file: stomach.nii.gz
# Removing empty segmentation file: vertebrae_C7.nii.gz
# Removing empty segmentation file: vertebrae_C5.nii.gz
# Removing empty segmentation file: esophagus.nii.gz
# Removing empty segmentation file: portal_vein_and_splenic_vein.nii.gz
# Removing empty segmentation file: brachiocephalic_trunk.nii.gz
# Removing empty segmentation file: common_carotid_artery_right.nii.gz
# Removing empty segmentation file: brain.nii.gz
# Removing empty segmentation file: brachiocephalic_vein_left.nii.gz
# Removing empty segmentation file: rib_right_3.nii.gz
# Removing empty segmentation file: vertebrae_T3.nii.gz
# Removing empty segmentation file: spinal_cord.nii.gz
# Removing empty segmentation file: brachiocephalic_vein_right.nii.gz
# Removing empty segmentation file: rib_left_11.nii.gz
# Removing empty segmentation file: subclavian_artery_left.nii.gz
# Removing empty segmentation file: trachea.nii.gz
# Removing empty segmentation file: vertebrae_T12.nii.gz
# Removing empty segmentation file: rib_right_10.nii.gz
# Removing empty segmentation file: rib_left_4.nii.gz
# Removing empty segmentation file: common_carotid_artery_left.nii.gz
# Removing empty segmentation file: rib_left_8.nii.gz
# Removing empty segmentation file: kidney_cyst_right.nii.gz
# Removing empty segmentation file: rib_left_2.nii.gz
# Removing empty segmentation file: kidney_left.nii.gz
# Removing empty segmentation file: rib_left_1.nii.gz
# Removing empty segmentation file: rib_right_11.nii.gz
# Removing empty segmentation file: scapula_right.nii.gz
# Removing empty segmentation file: lung_lower_lobe_right.nii.gz
# Removing empty segmentation file: clavicula_left.nii.gz
# Removing empty segmentation file: rib_right_1.nii.gz
# Removing empty segmentation file: autochthon_left.nii.gz
# Removing empty segmentation file: vertebrae_T7.nii.gz
# Removing empty segmentation file: rib_left_9.nii.gz
# Removing empty segmentation file: kidney_cyst_left.nii.gz
# Removing empty segmentation file: rib_right_4.nii.gz
# Removing empty segmentation file: autochthon_right.nii.gz
# Removing empty segmentation file: pancreas.nii.gz
# Removing empty segmentation file: rib_right_12.nii.gz
# Removing empty segmentation file: rib_right_2.nii.gz
# Removing empty segmentation file: vertebrae_C4.nii.gz
# Removing empty segmentation file: subclavian_artery_right.nii.gz
# Removing empty segmentation file: vertebrae_L5.nii.gz
# Removing empty segmentation file: adrenal_gland_right.nii.gz
# Removing empty segmentation file: vertebrae_T9.nii.gz
# Removing empty segmentation file: vertebrae_S1.nii.gz
# Removing empty segmentation file: rib_left_12.nii.gz
# Removing empty segmentation file: rib_right_5.nii.gz
# Removing empty segmentation file: vertebrae_T8.nii.gz
# Removing empty segmentation file: clavicula_right.nii.gz
# Removing empty segmentation file: lung_upper_lobe_right.nii.gz
# Removing empty segmentation file: vertebrae_L2.nii.gz
# Removing empty segmentation file: spleen.nii.gz
# Removing empty segmentation file: rib_left_6.nii.gz
# Removing empty segmentation file: vertebrae_C1.nii.gz
# Removing empty segmentation file: lung_upper_lobe_left.nii.gz
# Removing empty segmentation file: vertebrae_T2.nii.gz
# Removing empty segmentation file: rib_left_10.nii.gz
# Removing empty segmentation file: gallbladder.nii.gz
# Removing empty segmentation file: superior_vena_cava.nii.gz
# Removing empty segmentation file: vertebrae_T4.nii.gz
# Removing empty segmentation file: rib_right_7.nii.gz
# Removing empty segmentation file: lung_middle_lobe_right.nii.gz
# Removing empty segmentation file: kidney_right.nii.gz
# Removing empty segmentation file: sternum.nii.gz
# Removing empty segmentation file: rib_right_8.nii.gz
# Removing empty segmentation file: rib_left_7.nii.gz
# Removing empty segmentation file: adrenal_gland_left.nii.gz
# Removing empty segmentation file: inferior_vena_cava.nii.gz
# Removing empty segmentation file: skull.nii.gz
# Removing empty segmentation file: vertebrae_T1.nii.gz
# Removing empty segmentation file: vertebrae_T10.nii.gz
# Removing empty segmentation file: vertebrae_L3.nii.gz
# Removing empty segmentation file: costal_cartilages.nii.gz
# Removing empty segmentation file: humerus_right.nii.gz
# Removing empty segmentation file: vertebrae_L4.nii.gz
# Removing empty segmentation file: vertebrae_C6.nii.gz
# Removing empty segmentation file: thyroid_gland.nii.gz
# Removing empty segmentation file: scapula_left.nii.gz
# Removing empty segmentation file: duodenum.nii.gz
# Removing empty segmentation file: rib_right_9.nii.gz
# Removing empty segmentation file: vertebrae_L1.nii.gz
# Removing empty segmentation file: humerus_left.nii.gz
# Removing empty segmentation file: vertebrae_C2.nii.gz
# Removing empty segmentation file: vertebrae_T11.nii.gz
# Removing empty segmentation file: aorta.nii.gz
# Removing empty segmentation file: vertebrae_C3.nii.gz
# Removing empty segmentation file: heart.nii.gz
# Removing empty segmentation file: rib_left_5.nii.gz
# Removing empty segmentation file: rib_right_6.nii.gz
# Removing empty segmentation file: pulmonary_vein.nii.gz
# Removing empty segmentation file: atrial_appendage_left.nii.gz
# Removing empty segmentation file: lung_lower_lobe_left.nii.gz
# Removing empty segmentation file: vertebrae_T5.nii.gz

# %% [markdown]
# # Visualizer

# %%
# @title ##### Select the organs to be shown and then run the next cell to visualize them in 3d (select multiple with SHIFT or CTRL + Click)
import ipywidgets as widgets
from IPython.display import display
import os

# Assume output_dir is defined in a previous cell or define it here if needed
output_dir = "output_segments"

# Get list of segmentation files from the output directory
all_segmentation_files = [f for f in os.listdir(output_dir) if f.endswith(".nii.gz")]

# Extract organ names (remove .nii.gz extension)
valid_segmentation_names = [file_name.replace(".nii.gz", "") for file_name in all_segmentation_files]

# Sort the organ names alphabetically
valid_segmentation_names.sort()


# Create a dropdown widget to select organs
organ_selector = widgets.SelectMultiple(
    options=valid_segmentation_names,
    description='Select Organs:',
    disabled=False,
    style = {'description_width': 'initial'}
)

display(organ_selector)
# Out:
# SelectMultiple(description='Select Organs:', options=('colon', 'femur_left', 'femur_right', 'gluteus_maximus_l…

# %%
# @title 3d Visualization
import nibabel as nib
import pyvista as pv
from skimage import measure
import numpy as np
from scipy.ndimage import gaussian_filter
import colorsys


# This cell should be run after selecting organs in the previous cell

# Assume output_dir is defined in a previous cell or define it here if needed
# Assume organ_selector and its value are available from the previous cell

loaded_meshes = {}
plotter = pv.Plotter(notebook=True)
organ_controls = {}

# Load selected organ masks and create meshes
selected_organs = organ_selector.value

if not selected_organs:
    print("No organs selected. Please select organs in the previous cell.")
else:
    num_organs = len(selected_organs)
    for i, organ_name in enumerate(selected_organs):
        mask_file = os.path.join(output_dir, f"{organ_name}.nii.gz")
        if os.path.exists(mask_file):
            try:
                mask = nib.load(mask_file).get_fdata()
                mask_smoothed = gaussian_filter(mask.astype(float), sigma=1)
                verts, faces, _, _ = measure.marching_cubes(mask_smoothed, level=0.5, step_size=1)
                faces = np.hstack((np.ones((faces.shape[0], 1)) * 3, faces)).flatten().astype(np.int64)
                mesh = pv.PolyData(verts, faces)
                loaded_meshes[organ_name] = mesh

                # Calculate initial color using HSV
                hue = i / num_organs  # Distribute hues evenly
                rgb_color = colorsys.hsv_to_rgb(hue, 0.8, 0.8)  # Use a fixed saturation and value
                hex_color = '#%02x%02x%02x' % (int(rgb_color[0]*255), int(rgb_color[1]*255), int(rgb_color[2]*255))

                # Add mesh to plotter and store the actor
                actor = plotter.add_mesh(mesh, color=hex_color, opacity=0.6, name=organ_name)

                # Create controls for each organ
                color_picker = widgets.ColorPicker(concise=False, description='Color:', value=hex_color, disabled=False)
                opacity_slider = widgets.FloatSlider(value=0.6, min=0.0, max=1.0, step=0.05, description='Opacity:', disabled=False, continuous_update=True, orientation='horizontal', readout=True, readout_format='.2f')
                visibility_checkbox = widgets.Checkbox(value=True, description='Visible:', disabled=False)
                render_button = widgets.Button(description="Render Plot")

                # Store controls and actor
                organ_controls[organ_name] = {
                    'color_picker': color_picker,
                    'opacity_slider': opacity_slider,
                    'visibility_checkbox': visibility_checkbox,
                    'actor': actor
                }

                def update_color(change, actor=actor):
                    actor.prop.color = change['new']

                def update_opacity(change, actor=actor):
                    actor.prop.opacity = change['new']

                def update_visibility(change, actor=actor):
                    actor.SetVisibility(change['new'])


                color_picker.observe(update_color, names='value')
                opacity_slider.observe(update_opacity, names='value')
                visibility_checkbox.observe(update_visibility, names='value')
            except Exception as e:
                print(f"Could not generate mesh for {organ_name}: {e}")
                continue # Skip to the next organ if mesh generation fails


    # Display controls and plot

    def render(b=None): # Added b=None to accept button click event
      clear_output()
      for organ_name, controls in organ_controls.items():
          print(f"Controls for {organ_name}:")
          display(widgets.HBox([controls['color_picker'], controls['opacity_slider'], controls['visibility_checkbox']]))
      display(render_button)
      plotter.show(jupyter_backend='html')

      render_button.on_click(render)



    # Initial display of controls and plot
    render()
# Out:
# Controls for aorta:
# HBox(children=(ColorPicker(value='#cc2828', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Controls for duodenum:
# HBox(children=(ColorPicker(value='#ccb428', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Controls for gallbladder:
# HBox(children=(ColorPicker(value='#57cc28', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Controls for inferior_vena_cava:
# HBox(children=(ColorPicker(value='#28cc86', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Controls for liver:
# HBox(children=(ColorPicker(value='#2886cc', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Controls for pancreas:
# HBox(children=(ColorPicker(value='#5728cc', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Controls for portal_vein_and_splenic_vein:
# HBox(children=(ColorPicker(value='#cc28b4', description='Color:'), FloatSlider(value=0.6, description='Opacity…
# Button(description='Render Plot', style=ButtonStyle())
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…

# %% [markdown]
# # Evaluation
# Compare the model's predictions to professional predictions by loading both sets of segmentation masks for a selected subject.

# %% [markdown]
# Chosen metrics for comparing segmentation masks:
#  1. Dice Similarity Coefficient (Dice): Measures the overlap between two segmentation masks.
#     > Formula: **Dice = (2 * |A intersect B|) / (|A| + |B|)** Where A and B are the two segmentation masks.\
#     Range: 0 (no overlap) to 1 (perfect overlap). Higher is better.
#
#  2. Jaccard Index (IoU - Intersection over Union): Another measure of overlap, similar to Dice.
#     > Formula: **Jaccard = |A intersect B| / |A union B|**\
#       Range: 0 (no overlap) to 1 (perfect overlap). Higher is better.
#
#  3. Hausdorff Distance: Measures the maximum distance between points in the boundaries of the two segmentation masks.
#     > Formula: **Hausdorff(A, B) = max(h(A, B), h(B, A)) where h(A, B) = max_{a in A} min_{b in B} distance(a, b)**\
#       Lower is better, as it indicates the boundaries are closer.

# %%
# @title Calculating Metrics
from scipy.spatial.distance import directed_hausdorff
import numpy as np
import os
import nibabel as nib
import pandas as pd
from skimage.transform import resize
selected_organs = organ_selector.value

def calculate_metrics(mask1, mask2):
    """
    Calculates Dice coefficient, Jaccard index, and Hausdorff distance between two binary masks.

    Args:
        mask1 (np.ndarray): The first binary mask.
        mask2 (np.ndarray): The second binary mask.

    Returns:
        tuple: A tuple containing the Dice coefficient, Jaccard index, and Hausdorff distance.
               Returns (0.0, 0.0, np.inf) if either mask is empty for Dice and Jaccard,
               and np.inf for Hausdorff distance if either mask is empty.
    """
    # Ensure masks have the same shape
    if mask1.shape != mask2.shape:
        print(f"  Warning: Masks have different shapes: {mask1.shape} vs {mask2.shape}. Resizing the smaller mask.")
        # Determine which mask is smaller and resize it
        if np.prod(mask1.shape) < np.prod(mask2.shape):
            mask1 = resize(mask1, mask2.shape, order=0, preserve_range=True, anti_aliasing=False)
            mask1 = (mask1 > 0.5).astype(np.uint8) # Convert back to binary after resizing
        else:
            mask2 = resize(mask2, mask1.shape, order=0, preserve_range=True, anti_aliasing=False)
            mask2 = (mask2 > 0.5).astype(np.uint8) # Convert back to binary after resizing


    mask1_flat = mask1.flatten()
    mask2_flat = mask2.flatten()


    # Dice Coefficient
    intersection = np.sum(mask1_flat * mask2_flat)
    sum_masks = np.sum(mask1_flat) + np.sum(mask2_flat)
    dice = (2.0 * intersection) / sum_masks if sum_masks else 0.0

    # Jaccard Index
    union = np.sum(mask1_flat + mask2_flat - mask1_flat * mask2_flat)
    jaccard = intersection / union if union else 0.0

    # Hausdorff Distance
    coords1 = np.argwhere(mask1)
    coords2 = np.argwhere(mask2)
    hausdorff_distance = np.inf
    if coords1.shape[0] > 0 and coords2.shape[0] > 0:
        # Calculate directed Hausdorff distance in both directions and take the maximum
        h1 = directed_hausdorff(coords1, coords2)[0]
        h2 = directed_hausdorff(coords2, coords1)[0]
        hausdorff_distance = max(h1, h2)
    elif coords1.shape[0] > 0 or coords2.shape[0] > 0:
        # If one mask is empty and the other is not, Hausdorff distance is infinite
         hausdorff_distance = np.inf


    return dice, jaccard, hausdorff_distance

# Store calculated metrics
comparison_results = {}

# Assume selected_organs, selected_folder, and output_dir are defined in previous cells

# Construct the file path to the professional segmentation directory
professional_segmentation_dir = os.path.join(selected_folder, "segmentations")

# Iterate through the selected organs
for organ_name in selected_organs:
    print(f"Processing organ: {organ_name}")

    # Load professional mask
    professional_mask = None
    professional_file_path = os.path.join(professional_segmentation_dir, f"{organ_name}.nii.gz")
    if os.path.exists(professional_file_path):
        try:
            img = nib.load(professional_file_path)
            professional_mask = img.get_fdata()
            print(f"  Loaded professional mask for {organ_name}")
        except Exception as e:
            print(f"  Could not load professional mask for {organ_name}: {e}")
            professional_mask = None # Ensure mask is None if loading fails
    else:
        print(f"  Professional mask for {organ_name} not found.")


    # Load model mask
    model_mask = None
    model_file_path = os.path.join(output_dir, f"{organ_name}.nii.gz")
    if os.path.exists(model_file_path):
        try:
            img = nib.load(model_file_path)
            model_mask = img.get_fdata()
            print(f"  Loaded model mask for {organ_name}")
        except Exception as e:
            print(f"  Could not load model mask for {organ_name}: {e}")
            model_mask = None # Ensure mask is None if loading fails
    else:
         print(f"  Model mask for {organ_name} not found.")


    # Calculate metrics if both masks are loaded
    if professional_mask is not None and model_mask is not None:
        dice, jaccard, hausdorff = calculate_metrics(model_mask, professional_mask)
        comparison_results[organ_name] = {
            'dice': dice,
            'jaccard': jaccard,
            'hausdorff': hausdorff
        }
        print(f"  Metrics for {organ_name}: Dice={dice:.4f}, Jaccard={jaccard:.4f}, Hausdorff={hausdorff:.4f}")
    else:
        print(f"  Skipping metrics for {organ_name} due to missing mask(s).")

    # Explicitly delete masks to free up memory
    del professional_mask
    del model_mask


print("\nFinished calculating metrics for all selected organs.")

# Create a pandas DataFrame from the comparison_results dictionary
comparison_df = pd.DataFrame.from_dict(comparison_results, orient='index')
comparison_df.index.name = 'Organ'

# Store the current comparison results in the persistent dictionary, keyed by the selected model
# Assuming 'all_comparison_results' and 'model_selector' are available from previous cells
if 'all_comparison_results' not in globals():
    all_comparison_results = {}

selected_model = model_selector.value
all_comparison_results[selected_model] = comparison_df
# Out:
# Processing organ: aorta
#   Loaded professional mask for aorta
#   Loaded model mask for aorta
#   Metrics for aorta: Dice=0.3106, Jaccard=0.1838, Hausdorff=134.5623
# Processing organ: autochthon_left
#   Loaded professional mask for autochthon_left
#   Loaded model mask for autochthon_left
#   Metrics for autochthon_left: Dice=0.3684, Jaccard=0.2258, Hausdorff=48.1248
# Processing organ: autochthon_right
#   Loaded professional mask for autochthon_right
#   Loaded model mask for autochthon_right
#   Metrics for autochthon_right: Dice=0.0646, Jaccard=0.0334, Hausdorff=61.4329
# Processing organ: clavicula_left
#   Loaded professional mask for clavicula_left
#   Loaded model mask for clavicula_left
#   Metrics for clavicula_left: Dice=0.5264, Jaccard=0.3572, Hausdorff=38.6523
# Processing organ: colon
#   Loaded professional mask for colon
#   Loaded model mask for colon
#   Metrics for colon: Dice=0.8648, Jaccard=0.7619, Hausdorff=38.1838
# Processing organ: duodenum
#   Loaded professional mask for duodenum
#   Loaded model mask for duodenum
#   Metrics for duodenum: Dice=0.2550, Jaccard=0.1461, Hausdorff=45.7275
# Processing organ: esophagus
#   Loaded professional mask for esophagus
#   Loaded model mask for esophagus
#   Metrics for esophagus: Dice=0.1687, Jaccard=0.0921, Hausdorff=58.0861
# Processing organ: femur_left
#   Loaded professional mask for femur_left
#   Loaded model mask for femur_left
#   Metrics for femur_left: Dice=0.4327, Jaccard=0.2761, Hausdorff=142.5553
# Processing organ: femur_right
#   Loaded professional mask for femur_right
#   Loaded model mask for femur_right
#   Metrics for femur_right: Dice=0.3065, Jaccard=0.1810, Hausdorff=140.3745
# Processing organ: gluteus_maximus_left
#   Loaded professional mask for gluteus_maximus_left
#   Loaded model mask for gluteus_maximus_left
#   Metrics for gluteus_maximus_left: Dice=0.6890, Jaccard=0.5255, Hausdorff=118.5749
# Processing organ: gluteus_maximus_right
#   Loaded professional mask for gluteus_maximus_right
#   Loaded model mask for gluteus_maximus_right
#   Metrics for gluteus_maximus_right: Dice=0.6734, Jaccard=0.5076, Hausdorff=107.8147
# Processing organ: gluteus_medius_left
#   Loaded professional mask for gluteus_medius_left
#   Loaded model mask for gluteus_medius_left
#   Metrics for gluteus_medius_left: Dice=0.6362, Jaccard=0.4665, Hausdorff=128.0547
# Processing organ: gluteus_medius_right
#   Loaded professional mask for gluteus_medius_right
#   Loaded model mask for gluteus_medius_right
#   Metrics for gluteus_medius_right: Dice=0.4442, Jaccard=0.2855, Hausdorff=34.8855
# Processing organ: gluteus_minimus_left
#   Loaded professional mask for gluteus_minimus_left
#   Loaded model mask for gluteus_minimus_left
#   Metrics for gluteus_minimus_left: Dice=0.4295, Jaccard=0.2734, Hausdorff=128.3199
# Processing organ: gluteus_minimus_right
#   Loaded professional mask for gluteus_minimus_right
#   Loaded model mask for gluteus_minimus_right
#   Metrics for gluteus_minimus_right: Dice=0.2735, Jaccard=0.1584, Hausdorff=35.2420
# Processing organ: heart_atrium_left
#   Professional mask for heart_atrium_left not found.
#   Loaded model mask for heart_atrium_left
#   Skipping metrics for heart_atrium_left due to missing mask(s).
# Processing organ: heart_atrium_right
#   Professional mask for heart_atrium_right not found.
#   Loaded model mask for heart_atrium_right
#   Skipping metrics for heart_atrium_right due to missing mask(s).
# Processing organ: heart_myocardium
#   Professional mask for heart_myocardium not found.
#   Loaded model mask for heart_myocardium
#   Skipping metrics for heart_myocardium due to missing mask(s).
# Processing organ: heart_ventricle_left
#   Professional mask for heart_ventricle_left not found.
#   Loaded model mask for heart_ventricle_left
#   Skipping metrics for heart_ventricle_left due to missing mask(s).
# Processing organ: heart_ventricle_right
#   Professional mask for heart_ventricle_right not found.
#   Loaded model mask for heart_ventricle_right
#   Skipping metrics for heart_ventricle_right due to missing mask(s).
# Processing organ: hip_left
#   Loaded professional mask for hip_left
#   Loaded model mask for hip_left
#   Metrics for hip_left: Dice=0.7752, Jaccard=0.6329, Hausdorff=108.8210
# Processing organ: hip_right
#   Loaded professional mask for hip_right
#   Loaded model mask for hip_right
#   Metrics for hip_right: Dice=0.6100, Jaccard=0.4388, Hausdorff=69.4190
# Processing organ: humerus_left
#   Loaded professional mask for humerus_left
#   Loaded model mask for humerus_left
#   Metrics for humerus_left: Dice=0.6243, Jaccard=0.4538, Hausdorff=184.6862
# Processing organ: iliac_artery_left
#   Loaded professional mask for iliac_artery_left
#   Loaded model mask for iliac_artery_left
#   Metrics for iliac_artery_left: Dice=0.2319, Jaccard=0.1311, Hausdorff=89.0056
# Processing organ: iliac_vena_left
#   Loaded professional mask for iliac_vena_left
#   Loaded model mask for iliac_vena_left
#   Metrics for iliac_vena_left: Dice=0.1282, Jaccard=0.0685, Hausdorff=84.6286
# Processing organ: iliopsoas_left
#   Loaded professional mask for iliopsoas_left
#   Loaded model mask for iliopsoas_left
#   Metrics for iliopsoas_left: Dice=0.5598, Jaccard=0.3887, Hausdorff=116.5504
# Processing organ: iliopsoas_right
#   Loaded professional mask for iliopsoas_right
#   Loaded model mask for iliopsoas_right
#   Metrics for iliopsoas_right: Dice=0.0403, Jaccard=0.0206, Hausdorff=111.0180
# Processing organ: kidney_left
#   Loaded professional mask for kidney_left
#   Loaded model mask for kidney_left
#   Metrics for kidney_left: Dice=0.1424, Jaccard=0.0767, Hausdorff=53.7680
# Processing organ: kidney_right
#   Loaded professional mask for kidney_right
#   Loaded model mask for kidney_right
#   Metrics for kidney_right: Dice=0.8565, Jaccard=0.7490, Hausdorff=12.0000
# Processing organ: liver
#   Loaded professional mask for liver
#   Loaded model mask for liver
#   Metrics for liver: Dice=0.6345, Jaccard=0.4646, Hausdorff=84.6995
# Processing organ: lung_lower_lobe_left
#   Loaded professional mask for lung_lower_lobe_left
#   Loaded model mask for lung_lower_lobe_left
#   Metrics for lung_lower_lobe_left: Dice=0.6727, Jaccard=0.5068, Hausdorff=79.0822
# Processing organ: lung_lower_lobe_right
#   Loaded professional mask for lung_lower_lobe_right
#   Loaded model mask for lung_lower_lobe_right
#   Metrics for lung_lower_lobe_right: Dice=0.0552, Jaccard=0.0284, Hausdorff=64.1950
# Processing organ: lung_middle_lobe_right
#   Loaded professional mask for lung_middle_lobe_right
#   Loaded model mask for lung_middle_lobe_right
#   Metrics for lung_middle_lobe_right: Dice=0.0509, Jaccard=0.0261, Hausdorff=53.3010
# Processing organ: lung_upper_lobe_left
#   Loaded professional mask for lung_upper_lobe_left
#   Loaded model mask for lung_upper_lobe_left
#   Metrics for lung_upper_lobe_left: Dice=0.5689, Jaccard=0.3975, Hausdorff=109.8408
# Processing organ: lung_upper_lobe_right
#   Loaded professional mask for lung_upper_lobe_right
#   Loaded model mask for lung_upper_lobe_right
#   Metrics for lung_upper_lobe_right: Dice=0.0055, Jaccard=0.0028, Hausdorff=53.5910
# Processing organ: pancreas
#   Loaded professional mask for pancreas
#   Loaded model mask for pancreas
#   Metrics for pancreas: Dice=0.6341, Jaccard=0.4642, Hausdorff=12.7279
# Processing organ: portal_vein_and_splenic_vein
#   Loaded professional mask for portal_vein_and_splenic_vein
#   Loaded model mask for portal_vein_and_splenic_vein
#   Metrics for portal_vein_and_splenic_vein: Dice=0.5551, Jaccard=0.3842, Hausdorff=31.7805
# Processing organ: pulmonary_artery
#   Professional mask for pulmonary_artery not found.
#   Loaded model mask for pulmonary_artery
#   Skipping metrics for pulmonary_artery due to missing mask(s).
# Processing organ: rib_left_10
#   Loaded professional mask for rib_left_10
#   Loaded model mask for rib_left_10
#   Metrics for rib_left_10: Dice=0.0089, Jaccard=0.0045, Hausdorff=73.1163
# Processing organ: rib_left_11
#   Loaded professional mask for rib_left_11
#   Loaded model mask for rib_left_11
#   Metrics for rib_left_11: Dice=0.0656, Jaccard=0.0339, Hausdorff=52.0384
# Processing organ: rib_left_12
#   Loaded professional mask for rib_left_12
#   Loaded model mask for rib_left_12
#   Metrics for rib_left_12: Dice=0.7881, Jaccard=0.6503, Hausdorff=5.0990
# Processing organ: rib_left_2
#   Loaded professional mask for rib_left_2
#   Loaded model mask for rib_left_2
#   Metrics for rib_left_2: Dice=0.0137, Jaccard=0.0069, Hausdorff=71.4703
# Processing organ: rib_left_3
#   Loaded professional mask for rib_left_3
#   Loaded model mask for rib_left_3
#   Metrics for rib_left_3: Dice=0.3037, Jaccard=0.1790, Hausdorff=108.3744
# Processing organ: rib_left_4
#   Loaded professional mask for rib_left_4
#   Loaded model mask for rib_left_4
#   Metrics for rib_left_4: Dice=0.3074, Jaccard=0.1816, Hausdorff=121.8688
# Processing organ: rib_left_5
#   Loaded professional mask for rib_left_5
#   Loaded model mask for rib_left_5
#   Metrics for rib_left_5: Dice=0.2022, Jaccard=0.1125, Hausdorff=132.6989
# Processing organ: rib_left_6
#   Loaded professional mask for rib_left_6
#   Loaded model mask for rib_left_6
#   Metrics for rib_left_6: Dice=0.2441, Jaccard=0.1390, Hausdorff=72.1734
# Processing organ: rib_left_7
#   Loaded professional mask for rib_left_7
#   Loaded model mask for rib_left_7
#   Metrics for rib_left_7: Dice=0.2539, Jaccard=0.1454, Hausdorff=38.7427
# Processing organ: rib_left_8
#   Loaded professional mask for rib_left_8
#   Loaded model mask for rib_left_8
#   Metrics for rib_left_8: Dice=0.2174, Jaccard=0.1220, Hausdorff=108.4113
# Processing organ: rib_left_9
#   Loaded professional mask for rib_left_9
#   Loaded model mask for rib_left_9
#   Metrics for rib_left_9: Dice=0.0000, Jaccard=0.0000, Hausdorff=169.1686
# Processing organ: rib_right_6
#   Loaded professional mask for rib_right_6
#   Loaded model mask for rib_right_6
#   Metrics for rib_right_6: Dice=0.0000, Jaccard=0.0000, Hausdorff=104.0529
# Processing organ: sacrum
#   Loaded professional mask for sacrum
#   Loaded model mask for sacrum
#   Metrics for sacrum: Dice=0.5811, Jaccard=0.4095, Hausdorff=20.1990
# Processing organ: scapula_left
#   Loaded professional mask for scapula_left
#   Loaded model mask for scapula_left
#   Metrics for scapula_left: Dice=0.6109, Jaccard=0.4398, Hausdorff=132.1363
# Processing organ: scapula_right
#   Loaded professional mask for scapula_right
#   Loaded model mask for scapula_right
#   Metrics for scapula_right: Dice=0.0009, Jaccard=0.0005, Hausdorff=88.5494
# Processing organ: small_bowel
#   Loaded professional mask for small_bowel
#   Loaded model mask for small_bowel
#   Metrics for small_bowel: Dice=0.8535, Jaccard=0.7445, Hausdorff=41.1582
# Processing organ: spleen
#   Loaded professional mask for spleen
#   Loaded model mask for spleen
#   Metrics for spleen: Dice=0.0654, Jaccard=0.0338, Hausdorff=81.7985
# Processing organ: stomach
#   Loaded professional mask for stomach
#   Loaded model mask for stomach
#   Metrics for stomach: Dice=0.4072, Jaccard=0.2557, Hausdorff=38.7943
# Processing organ: trachea
#   Loaded professional mask for trachea
#   Loaded model mask for trachea
#   Metrics for trachea: Dice=0.8455, Jaccard=0.7323, Hausdorff=19.6723
# Processing organ: urinary_bladder
#   Loaded professional mask for urinary_bladder
#   Loaded model mask for urinary_bladder
#   Metrics for urinary_bladder: Dice=0.3882, Jaccard=0.2409, Hausdorff=25.8070
# Processing organ: vertebrae_L5
#   Loaded professional mask for vertebrae_L5
#   Loaded model mask for vertebrae_L5
#   Metrics for vertebrae_L5: Dice=0.0066, Jaccard=0.0033, Hausdorff=40.3113
# Processing organ: vertebrae_T1
#   Loaded professional mask for vertebrae_T1
#   Loaded model mask for vertebrae_T1
#   Metrics for vertebrae_T1: Dice=0.0000, Jaccard=0.0000, Hausdorff=38.1314
# Processing organ: vertebrae_T6
#   Loaded professional mask for vertebrae_T6
#   Loaded model mask for vertebrae_T6
#   Metrics for vertebrae_T6: Dice=0.0000, Jaccard=0.0000, Hausdorff=36.9053
# Processing organ: vertebrae_T7
#   Loaded professional mask for vertebrae_T7
#   Loaded model mask for vertebrae_T7
#   Metrics for vertebrae_T7: Dice=0.1290, Jaccard=0.0690, Hausdorff=27.4591
# Processing organ: vertebrae_T8
#   Loaded professional mask for vertebrae_T8
#   Loaded model mask for vertebrae_T8
#   Metrics for vertebrae_T8: Dice=0.2323, Jaccard=0.1314, Hausdorff=28.8791
# Processing organ: vertebrae_T9
#   Loaded professional mask for vertebrae_T9
#   Loaded model mask for vertebrae_T9
#   Metrics for vertebrae_T9: Dice=0.2165, Jaccard=0.1214, Hausdorff=18.4391
#
# Finished calculating metrics for all selected organs.

# %%
# @title Results Table
import pandas as pd
import numpy as np
from IPython.display import display

# Assume 'all_comparison_results' and 'model_selector' are available from previous cells

print(f"\nComparison results for '{selected_model}':")

# Set pandas options to display the full DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


# Display the DataFrame
display(comparison_df)

# Analyze the results for the current model
print(f"\nAnalysis of Segmentation Metrics for '{selected_model}':")
print("-" * 30)

if not comparison_df.empty:
    # Find organs with highest/lowest Dice and Jaccard scores
    highest_dice_organ = comparison_df['dice'].idxmax()
    lowest_dice_organ = comparison_df['dice'].idxmin()
    highest_jaccard_organ = comparison_df['jaccard'].idxmax()
    lowest_jaccard_organ = comparison_df['jaccard'].idxmin()

    # Find organs with highest/lowest Hausdorff distances
    # Exclude infinite Hausdorff distances for min calculation if any
    finite_hausdorff = comparison_df[comparison_df['hausdorff'] != np.inf]['hausdorff']
    highest_hausdorff_organ = comparison_df['hausdorff'].idxmax()

    if not finite_hausdorff.empty:
        lowest_hausdorff_organ = finite_hausdorff.idxmin()
    else:
        lowest_hausdorff_organ = "N/A (All Hausdorff distances are infinite)"


    print(f"Overall Performance (based on selected organs):")
    print(f"- Dice Coefficient: Higher values indicate better overlap.")
    print(f"  Highest Dice: '{highest_dice_organ}' ({comparison_df.loc[highest_dice_organ, 'dice']:.4f})")
    print(f"  Lowest Dice: '{lowest_dice_organ}' ({comparison_df.loc[lowest_dice_organ, 'dice']:.4f})")
    print(f"- Jaccard Index (IoU): Higher values indicate better overlap.")
    print(f"  Highest Jaccard: '{highest_jaccard_organ}' ({comparison_df.loc[highest_jaccard_organ, 'jaccard']:.4f})")
    print(f"  Lowest Jaccard: '{lowest_jaccard_organ}' ({comparison_df.loc[lowest_jaccard_organ, 'jaccard']:.4f})")
    print(f"- Hausdorff Distance: Lower values indicate better boundary agreement.")
    print(f"  Highest Hausdorff: '{highest_hausdorff_organ}' ({comparison_df.loc[highest_hausdorff_organ, 'hausdorff']:.4f})")
    if lowest_hausdorff_organ != "N/A (All Hausdorff distances are infinite)":
         print(f"  Lowest Hausdorff: '{lowest_hausdorff_organ}' ({comparison_df.loc[lowest_hausdorff_organ, 'hausdorff']:.4f})")
    else:
        print(f"  Lowest Hausdorff: {lowest_hausdorff_organ}")

else:
    print("No comparison results to analyze.")

# Optionally, display all stored results
print("\nAll Stored Comparison Results:")
print("=" * 30)
for model_name, results_df in all_comparison_results.items():
    print(f"\nResults for Model: {model_name}")
    display(results_df)

# Reset pandas options to default (optional, but good practice)
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')
# Out:
# Comparison results for 'STU-Net-B':
#                                   dice   jaccard   hausdorff
# Organ
# aorta                         0.259097  0.148829  129.011627
# autochthon_left               0.464430  0.302448   34.014703
# autochthon_right              0.066404  0.034342   64.892218
# colon                         0.823198  0.699522   35.298725
# duodenum                      0.068830  0.035642   60.514461
# esophagus                     0.175583  0.096241   50.299105
# femur_left                    0.433941  0.277091  142.555252
# femur_right                   0.063050  0.032551  140.132081
# gluteus_maximus_left          0.535121  0.365301  126.779336
# gluteus_maximus_right         0.005485  0.002750  128.117134
# gluteus_medius_left           0.351696  0.213369  132.969921
# gluteus_medius_right          0.064385  0.033263   53.525695
# hip_left                      0.401289  0.251008  123.850717
# hip_right                     0.215666  0.120866   82.903558
# humerus_left                  0.642040  0.472797  182.945347
# humerus_right                 0.104953  0.055383   18.788294
# iliac_artery_left             0.099363  0.052279   87.407094
# iliac_artery_right            0.010165  0.005109   97.355020
# iliac_vena_left               0.147251  0.079477   81.473922
# iliopsoas_left                0.191112  0.105652  115.043470
# iliopsoas_right               0.006036  0.003027  167.755775
# kidney_left                   0.450211  0.290498   73.006849
# kidney_right                  0.500023  0.333354   18.138357
# liver                         0.608224  0.437013   74.759615
# lung_lower_lobe_left          0.773376  0.630492   90.669730
# lung_lower_lobe_right         0.271342  0.156967   55.578773
# lung_middle_lobe_right        0.013723  0.006909   92.568893
# lung_upper_lobe_left          0.552050  0.381263  113.859563
# lung_upper_lobe_right         0.016647  0.008393   56.231664
# pancreas                      0.280093  0.162854   17.204651
# portal_vein_and_splenic_vein  0.080050  0.041694   35.114100
# rib_left_10                   0.376634  0.232008  109.197070
# rib_left_11                   0.574713  0.403226   94.720642
# rib_left_12                   0.661509  0.494220    9.433981
# rib_left_3                    0.322119  0.191979  110.440029
# rib_left_4                    0.208581  0.116434  129.390881
# rib_left_5                    0.051740  0.026557  107.689368
# rib_left_6                    0.000000  0.000000  131.015266
# rib_left_7                    0.077096  0.040094  108.314357
# rib_left_8                    0.161616  0.087912   93.669632
# rib_left_9                    0.156141  0.084682   99.242128
# sacrum                        0.407911  0.256211   80.529498
# scapula_left                  0.586723  0.415150  127.784976
# scapula_right                 0.015555  0.007838   78.243211
# small_bowel                   0.801133  0.668241   47.021272
# spleen                        0.306738  0.181152   63.568860
# stomach                       0.125536  0.066972   49.081565
# trachea                       0.774212  0.631604   22.494444
# urinary_bladder               0.427513  0.271871  103.252119
# vertebrae_L5                  0.000218  0.000109   37.549967
# vertebrae_T4                  0.000000  0.000000   50.852729
# vertebrae_T6                  0.000000  0.000000   42.532341
# vertebrae_T7                  0.040482  0.020659   31.591138
# vertebrae_T8                  0.000000  0.000000   45.705580
# Analysis of Segmentation Metrics for 'STU-Net-B':
# ------------------------------
# Overall Performance (based on selected organs):
# - Dice Coefficient: Higher values indicate better overlap.
#   Highest Dice: 'colon' (0.8232)
#   Lowest Dice: 'rib_left_6' (0.0000)
# - Jaccard Index (IoU): Higher values indicate better overlap.
#   Highest Jaccard: 'colon' (0.6995)
#   Lowest Jaccard: 'rib_left_6' (0.0000)
# - Hausdorff Distance: Lower values indicate better boundary agreement.
#   Highest Hausdorff: 'humerus_left' (182.9453)
#   Lowest Hausdorff: 'rib_left_12' (9.4340)
#
# All Stored Comparison Results:
# ==============================
#
# Results for Model: totalSegmentator
#                                   dice   jaccard  hausdorff
# Organ
# adrenal_gland_left            0.696203  0.533981   2.449490
# adrenal_gland_right           0.930474  0.869988   2.000000
# aorta                         0.987893  0.976075   2.236068
# atrial_appendage_left         0.956734  0.917057   2.000000
# autochthon_left               0.983372  0.967287   2.000000
# autochthon_right              0.982863  0.966303   2.000000
# brachiocephalic_trunk         0.971692  0.944942   1.414214
# brachiocephalic_vein_left     0.980409  0.961571   1.000000
# brachiocephalic_vein_right    0.976883  0.954810   1.000000
# clavicula_left                0.977373  0.955748   2.236068
# clavicula_right               0.980127  0.961029   1.000000
# colon                         0.938965  0.884952  25.961510
# common_carotid_artery_left    0.925498  0.861328   2.236068
# common_carotid_artery_right   0.958658  0.920598   1.000000
# costal_cartilages             0.933565  0.875408  14.696938
# duodenum                      0.942000  0.890360   3.741657
# esophagus                     0.958081  0.919535   2.000000
# femur_left                    0.990864  0.981892   2.000000
# femur_right                   0.990985  0.982130   1.414214
# gallbladder                   0.924145  0.858987   2.449490
# gluteus_maximus_left          0.981150  0.962998   2.828427
# gluteus_maximus_right         0.981862  0.964370   2.236068
# gluteus_medius_left           0.984175  0.968843   1.414214
# gluteus_medius_right          0.982868  0.966314   1.414214
# gluteus_minimus_left          0.960892  0.924727   1.732051
# gluteus_minimus_right         0.973439  0.948253   1.414214
# heart                         0.961162  0.925228   4.358899
# hip_left                      0.991543  0.983227  32.202484
# hip_right                     0.993001  0.986099   2.000000
# humerus_left                  0.965210  0.932759   2.449490
# humerus_right                 0.981787  0.964225   2.449490
# iliac_artery_left             0.959104  0.921422   2.000000
# iliac_artery_right            0.944108  0.894133   2.000000
# iliac_vena_left               0.953206  0.910595   2.236068
# iliac_vena_right              0.945425  0.896498   1.732051
# iliopsoas_left                0.974155  0.949612   3.605551
# iliopsoas_right               0.978259  0.957443   2.236068
# inferior_vena_cava            0.962483  0.927679   2.236068
# kidney_left                   0.966039  0.934310   4.000000
# kidney_right                  0.987066  0.974462   2.236068
# liver                         0.991646  0.983431  31.764760
# lung_lower_lobe_left          0.990799  0.981765   7.141428
# lung_lower_lobe_right         0.990330  0.980846   2.828427
# lung_middle_lobe_right        0.945691  0.896976  41.785165
# lung_upper_lobe_left          0.994980  0.990011   3.605551
# lung_upper_lobe_right         0.982891  0.966357  32.710854
# pancreas                      0.931784  0.872280   9.695360
# portal_vein_and_splenic_vein  0.888907  0.800030  21.189620
# pulmonary_vein                0.967681  0.937386   2.000000
# rib_left_1                    0.894557  0.809230   6.403124
# rib_left_10                   0.979916  0.960623   1.000000
# rib_left_11                   0.978414  0.957740   1.000000
# rib_left_12                   0.874680  0.777273   4.690416
# rib_left_2                    0.972467  0.946409   1.414214
# rib_left_3                    0.959081  0.921379   4.472136
# rib_left_4                    0.972084  0.945683   1.732051
# rib_left_5                    0.974855  0.950944   2.000000
# rib_left_6                    0.969880  0.941520   2.449490
# rib_left_7                    0.984954  0.970354   1.000000
# rib_left_8                    0.984665  0.969794   2.236068
# rib_left_9                    0.980810  0.962342   2.449490
# rib_right_1                   0.958191  0.919737   3.316625
# rib_right_10                  0.972441  0.946361   2.236068
# rib_right_11                  0.974421  0.950119   1.000000
# rib_right_12                  0.923588  0.858025   2.449490
# rib_right_2                   0.975399  0.951979   1.414214
# rib_right_3                   0.974137  0.949577   2.000000
# rib_right_4                   0.975135  0.951476   1.414214
# rib_right_5                   0.968839  0.939561   2.449490
# rib_right_6                   0.980309  0.961378   1.414214
# rib_right_7                   0.983380  0.967303   1.000000
# rib_right_8                   0.979756  0.960316   1.414214
# rib_right_9                   0.984145  0.968785   1.000000
# sacrum                        0.978052  0.957047   7.280110
# scapula_left                  0.979410  0.959651   3.316625
# scapula_right                 0.977866  0.956691   1.414214
# skull                         0.910476  0.835664   3.605551
# small_bowel                   0.938800  0.884660  28.583212
# spinal_cord                   0.960072  0.923209   1.414214
# spleen                        0.986885  0.974110   4.690416
# sternum                       0.969405  0.940627   1.732051
# stomach                       0.961237  0.925366  28.635642
# subclavian_artery_left        0.952796  0.909847   2.828427
# subclavian_artery_right       0.959927  0.922941   2.828427
# superior_vena_cava            0.985326  0.971076   1.000000
# thyroid_gland                 0.940423  0.887545   1.732051
# trachea                       0.978885  0.958644   4.123106
# urinary_bladder               0.942573  0.891383  12.727922
# vertebrae_C7                  0.927263  0.864391   7.681146
# vertebrae_L1                  0.990931  0.982025   1.000000
# vertebrae_L2                  0.991276  0.982702   1.000000
# vertebrae_L3                  0.991045  0.982249   2.000000
# vertebrae_L4                  0.991334  0.982817   1.000000
# vertebrae_L5                  0.989644  0.979501   1.414214
# vertebrae_S1                  0.968492  0.938910   2.000000
# vertebrae_T1                  0.982568  0.965733   1.000000
# vertebrae_T10                 0.987408  0.975130   1.414214
# vertebrae_T11                 0.986047  0.972477   2.236068
# vertebrae_T12                 0.989241  0.978711   1.414214
# vertebrae_T2                  0.987473  0.975256   1.414214
# vertebrae_T3                  0.989569  0.979354   1.000000
# vertebrae_T4                  0.988867  0.977978   1.000000
# vertebrae_T5                  0.988828  0.977902   3.000000
# vertebrae_T6                  0.988512  0.977285   1.000000
# vertebrae_T7                  0.987681  0.975662   1.000000
# vertebrae_T8                  0.989796  0.979798   1.000000
# vertebrae_T9                  0.989432  0.979086   1.000000
# Results for Model: MONAI SegResNet
#                                   dice   jaccard   hausdorff
# Organ
# adrenal_gland_left            0.000000  0.000000   18.894444
# adrenal_gland_right           0.806536  0.675794    3.741657
# aorta                         0.956558  0.916732    2.828427
# autochthon_left               0.949806  0.904411    3.000000
# autochthon_right              0.956149  0.915982    3.000000
# clavicula_left                0.935203  0.878292    3.000000
# clavicula_right               0.953585  0.911287    2.236068
# colon                         0.891935  0.804949   32.264532
# duodenum                      0.862767  0.758655   20.223748
# esophagus                     0.871711  0.772595    4.358899
# femur_left                    0.954914  0.913718    3.316625
# femur_right                   0.963369  0.929327    3.000000
# gallbladder                   0.807904  0.677717    5.916080
# gluteus_maximus_left          0.948212  0.901523    8.124038
# gluteus_maximus_right         0.951372  0.907254    5.000000
# gluteus_medius_left           0.953385  0.910923    3.316625
# gluteus_medius_right          0.933729  0.875695    5.744563
# gluteus_minimus_left          0.906249  0.828570    4.358899
# gluteus_minimus_right         0.917687  0.847894    3.464102
# hip_left                      0.974586  0.950431    3.000000
# hip_right                     0.971886  0.945309    3.000000
# humerus_left                  0.929255  0.867859    2.236068
# humerus_right                 0.933661  0.875576    3.000000
# iliac_artery_left             0.866641  0.764666   10.099505
# iliac_artery_right            0.842053  0.727195    9.219544
# iliac_vena_left               0.869148  0.768579   13.674794
# iliac_vena_right              0.842802  0.728312   13.453624
# iliopsoas_left                0.933606  0.875480    7.141428
# iliopsoas_right               0.933104  0.874597    6.082763
# inferior_vena_cava            0.897871  0.814670    6.403124
# kidney_left                   0.948049  0.901230    3.741657
# kidney_right                  0.958023  0.919427   32.310989
# liver                         0.977806  0.956575   35.972211
# lung_lower_lobe_left          0.971549  0.944672   10.954451
# lung_lower_lobe_right         0.976664  0.954392    7.280110
# lung_middle_lobe_right        0.889903  0.801645   38.639358
# lung_upper_lobe_left          0.986079  0.972541    4.472136
# lung_upper_lobe_right         0.967653  0.937333   24.879711
# pancreas                      0.891320  0.803947    6.403124
# portal_vein_and_splenic_vein  0.825570  0.702953   22.912878
# rib_left_1                    0.885727  0.794892    6.403124
# rib_left_10                   0.885053  0.793807   27.586228
# rib_left_11                   0.929617  0.868491    1.414214
# rib_left_12                   0.820059  0.695000    3.741657
# rib_left_2                    0.898229  0.815260   12.206556
# rib_left_3                    0.902187  0.821803    4.690416
# rib_left_4                    0.865656  0.763134   30.757113
# rib_left_5                    0.842608  0.728023   18.708287
# rib_left_6                    0.892914  0.806544   20.346990
# rib_left_7                    0.910221  0.835234   24.062419
# rib_left_8                    0.948691  0.902390    2.236068
# rib_left_9                    0.896982  0.813207    4.242641
# rib_right_1                   0.873046  0.774695    3.162278
# rib_right_10                  0.876572  0.780266    4.582576
# rib_right_11                  0.916237  0.845422    1.414214
# rib_right_12                  0.853333  0.744186    3.316625
# rib_right_2                   0.915948  0.844930    1.414214
# rib_right_3                   0.918062  0.848534   14.696938
# rib_right_4                   0.936084  0.879848    1.414214
# rib_right_5                   0.935300  0.878464    7.280110
# rib_right_6                   0.897081  0.813370   16.401219
# rib_right_7                   0.905408  0.827164   18.110770
# rib_right_8                   0.884600  0.793079   16.401219
# rib_right_9                   0.925245  0.860889    2.000000
# sacrum                        0.833005  0.713804   15.000000
# scapula_left                  0.940400  0.887505   29.816103
# scapula_right                 0.941207  0.888943    6.633250
# small_bowel                   0.882081  0.789038   28.390139
# spleen                        0.975848  0.952836    5.385165
# stomach                       0.900849  0.819586   50.842895
# trachea                       0.939359  0.885652    4.000000
# urinary_bladder               0.923794  0.858380    7.280110
# vertebrae_C6                  0.000000  0.000000         inf
# vertebrae_C7                  0.894305  0.808816    5.099020
# vertebrae_L1                  0.961128  0.925164    4.123106
# vertebrae_L2                  0.960710  0.924390    3.741657
# vertebrae_L3                  0.953044  0.910300  135.974262
# vertebrae_L4                  0.954312  0.912616    3.000000
# vertebrae_L5                  0.946705  0.898804    9.486833
# vertebrae_T1                  0.940770  0.888165    4.000000
# vertebrae_T10                 0.955199  0.914240    3.000000
# vertebrae_T11                 0.956033  0.915769    3.741657
# vertebrae_T12                 0.956081  0.915858   18.681542
# vertebrae_T2                  0.938547  0.884211   13.416408
# vertebrae_T3                  0.903080  0.823288    4.242641
# vertebrae_T4                  0.894484  0.809110    7.141428
# vertebrae_T5                  0.909727  0.834403   15.264338
# vertebrae_T6                  0.929930  0.869036   72.284161
# vertebrae_T7                  0.941428  0.889338    3.464102
# vertebrae_T8                  0.954247  0.912497    2.449490
# vertebrae_T9                  0.956577  0.916767    2.449490
# Results for Model: STU-Net-B
#                                   dice   jaccard   hausdorff
# Organ
# aorta                         0.259097  0.148829  129.011627
# autochthon_left               0.464430  0.302448   34.014703
# autochthon_right              0.066404  0.034342   64.892218
# colon                         0.823198  0.699522   35.298725
# duodenum                      0.068830  0.035642   60.514461
# esophagus                     0.175583  0.096241   50.299105
# femur_left                    0.433941  0.277091  142.555252
# femur_right                   0.063050  0.032551  140.132081
# gluteus_maximus_left          0.535121  0.365301  126.779336
# gluteus_maximus_right         0.005485  0.002750  128.117134
# gluteus_medius_left           0.351696  0.213369  132.969921
# gluteus_medius_right          0.064385  0.033263   53.525695
# hip_left                      0.401289  0.251008  123.850717
# hip_right                     0.215666  0.120866   82.903558
# humerus_left                  0.642040  0.472797  182.945347
# humerus_right                 0.104953  0.055383   18.788294
# iliac_artery_left             0.099363  0.052279   87.407094
# iliac_artery_right            0.010165  0.005109   97.355020
# iliac_vena_left               0.147251  0.079477   81.473922
# iliopsoas_left                0.191112  0.105652  115.043470
# iliopsoas_right               0.006036  0.003027  167.755775
# kidney_left                   0.450211  0.290498   73.006849
# kidney_right                  0.500023  0.333354   18.138357
# liver                         0.608224  0.437013   74.759615
# lung_lower_lobe_left          0.773376  0.630492   90.669730
# lung_lower_lobe_right         0.271342  0.156967   55.578773
# lung_middle_lobe_right        0.013723  0.006909   92.568893
# lung_upper_lobe_left          0.552050  0.381263  113.859563
# lung_upper_lobe_right         0.016647  0.008393   56.231664
# pancreas                      0.280093  0.162854   17.204651
# portal_vein_and_splenic_vein  0.080050  0.041694   35.114100
# rib_left_10                   0.376634  0.232008  109.197070
# rib_left_11                   0.574713  0.403226   94.720642
# rib_left_12                   0.661509  0.494220    9.433981
# rib_left_3                    0.322119  0.191979  110.440029
# rib_left_4                    0.208581  0.116434  129.390881
# rib_left_5                    0.051740  0.026557  107.689368
# rib_left_6                    0.000000  0.000000  131.015266
# rib_left_7                    0.077096  0.040094  108.314357
# rib_left_8                    0.161616  0.087912   93.669632
# rib_left_9                    0.156141  0.084682   99.242128
# sacrum                        0.407911  0.256211   80.529498
# scapula_left                  0.586723  0.415150  127.784976
# scapula_right                 0.015555  0.007838   78.243211
# small_bowel                   0.801133  0.668241   47.021272
# spleen                        0.306738  0.181152   63.568860
# stomach                       0.125536  0.066972   49.081565
# trachea                       0.774212  0.631604   22.494444
# urinary_bladder               0.427513  0.271871  103.252119
# vertebrae_L5                  0.000218  0.000109   37.549967
# vertebrae_T4                  0.000000  0.000000   50.852729
# vertebrae_T6                  0.000000  0.000000   42.532341
# vertebrae_T7                  0.040482  0.020659   31.591138
# vertebrae_T8                  0.000000  0.000000   45.705580

# %%
# @title ##### Save results file
# Export the DataFrame to a CSV file
csv_filename = f"{selected_model}_segmentation_comparison_results.csv"
comparison_df.to_csv(csv_filename, index=True)

print(f"Comparison results exported to {csv_filename}")

# Provide a download link
from google.colab import files
files.download(csv_filename)
